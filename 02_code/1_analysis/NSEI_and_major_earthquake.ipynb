# %% [markdown]
# ## This file aim to analyse the Market Performance in a time range and Time for the Market Recover

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta

# %% [markdown]
# ## Merge NSEI.csv and NSEI_companies_stock.csv

# %%
# Load datasets
df_earthquake = pd.read_csv('clean_major_earthquakes.csv', parse_dates=['date']) # parse_dates convert the 'date' column from a string(text) format into a datatime format
df_stocks = pd.read_csv('NSEI_companies_stock.csv', parse_dates=['Date'])
df_companies = pd.read_csv('NSEI.csv')

# %%
# Display dataset
print(df_stocks.head())
print('---')
print(df_earthquake.head())
print('---')
print(df_companies.head())
# Out:
#         Date        Open       Close   Volume       Ticker
# 0 2007-01-02  136.324896  137.522079  1737983  HINDALCO.NS
# 1 2007-01-03  139.028205  138.410309  6568517  HINDALCO.NS
# 2 2007-01-04  138.255819  135.011826  5541476  HINDALCO.NS
# 3 2007-01-05  134.278063  132.154022  5296083  HINDALCO.NS
# 4 2007-01-08  131.381593  129.025848  5202449  HINDALCO.NS
# ---
#    tsunami  significance   data_type  magnitude              state  longitude  \
# 0        0           613  earthquake        6.3   Papua New Guinea    146.884
# 1        0           557  earthquake        6.0          Indonesia    101.032
# 2        0           671  earthquake        6.6             Canada   -130.746
# 3        0           630  earthquake        6.4             Canada   -130.542
# 4        0           920  earthquake        6.2             Greece     22.693
#
#    latitude  depth       date                   time
# 0    -5.878   34.0 2008-01-01  18:54:59.010000+00:00
# 1    -2.782   35.0 2008-01-04  07:29:18.300000+00:00
# 2    51.254   15.0 2008-01-05  11:01:06.110000+00:00
# 3    51.163   10.0 2008-01-05  11:44:48.170000+00:00
# 4    37.216   75.0 2008-01-06  05:14:20.180000+00:00
# ---
#           Ticker   Company_name     Industry
# 0    HINDALCO.NS       HINDALCO    ALUMINIUM
# 1  BAJAJ-AUTO.NS     BAJAJ AUTO  AUTOMOBILES
# 2   EICHERMOT.NS  EICHER MOTORS  AUTOMOBILES
# 3  HEROMOTOCO.NS  HERO MOTOCORP  AUTOMOBILES
# 4         M&M.NS            M&M  AUTOMOBILES

# %%
# Check for missing, duplicate data

# 0. Convert 'Date' column to string to ensure .str accessor works
df_stocks['Date'] = df_stocks['Date'].astype(str)

# 1. Remove rows where the 'Date' column doesn't match the expected date format
df_stocks = df_stocks[df_stocks['Date'].str.match(r'\d{4}-\d{2}-\d{2}', na=False)]

# 2. Convert the 'Date' column to datetime
df_stocks['Date'] = pd.to_datetime(df_stocks['Date'], format='%Y-%m-%d', errors='coerce')

# %%
# 3. Check for rows with invalid dates
invalid_dates = df_stocks[df_stocks['Date'].isna()]
print("Rows with invalid dates:")
print(invalid_dates)
# Out:
# Rows with invalid dates:
# Empty DataFrame
# Columns: [Date, Open, Close, Volume, Ticker]
# Index: []

# %%
# 4. Check for missing values in each column
missing_values = df_stocks.isnull().sum()
print("\nMissing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Date      0
# Open      0
# Close     0
# Volume    0
# Ticker    0
# dtype: int64

# %%
# 5. Check for missing rows (e.g., gaps in the Date column)
full_date_range = pd.date_range(start=df_stocks['Date'].min(), end=df_stocks['Date'].max(), freq='D')
missing_dates = full_date_range.difference(df_stocks['Date'])
print("\nMissing dates:")
print(missing_dates)
# Out:
# Missing dates:
# DatetimeIndex(['2007-01-06', '2007-01-07', '2007-01-13', '2007-01-14',
#                '2007-01-20', '2007-01-21', '2007-01-26', '2007-01-27',
#                '2007-01-28', '2007-01-30',
#                ...
#                '2025-01-25', '2025-01-26', '2025-02-02', '2025-02-08',
#                '2025-02-09', '2025-02-15', '2025-02-16', '2025-02-22',
#                '2025-02-23', '2025-02-26'],
#               dtype='datetime64[ns]', length=2152, freq=None)

# %%
# 6. Check for duplicate rows
duplicate_rows = df_stocks[df_stocks.duplicated()]
print("\nDuplicate rows:")
print(duplicate_rows)
# Out:
# Duplicate rows:
# Empty DataFrame
# Columns: [Date, Open, Close, Volume, Ticker]
# Index: []

# %%
# 7. Check for invalid values (e.g., Volume = 0)
invalid_volume = df_stocks[df_stocks['Volume'] == 0]
print("\nRows with Volume = 0:")
print(invalid_volume)
# Out:
# Rows with Volume = 0:
#              Date        Open       Close  Volume       Ticker
# 471    2008-11-27   46.029655   46.029655       0  HINDALCO.NS
# 569    2009-04-30   47.035995   47.035995       0  HINDALCO.NS
# 683    2009-10-13  114.080147  114.080147       0  HINDALCO.NS
# 1802   2014-04-24  134.538422  134.538422       0  HINDALCO.NS
# 1919   2014-10-15  140.800400  140.800400       0  HINDALCO.NS
# ...           ...         ...         ...     ...          ...
# 213240 2008-11-27  124.665680  124.665680       0    GRASIM.NS
# 213338 2009-04-30  244.242981  244.242981       0    GRASIM.NS
# 213452 2009-10-13  331.569641  331.569641       0    GRASIM.NS
# 214571 2014-04-24  400.301636  400.301636       0    GRASIM.NS
# 214688 2014-10-15  496.190796  496.190796       0    GRASIM.NS
#
# [1072 rows x 5 columns]

# %%
# Merge df_stocks with df_companies on 'Ticker'
merged_df = pd.merge(
    df_stocks, 
    df_companies, 
    on='Ticker', 
    how='left'  # Use 'left' to keep all rows from df_stocks
)

# Reorder the columns
column_order = ['Ticker', 'Company_name', 'Industry', 'Date', 'Open', 'Close', 'Volume']
merged_df = merged_df[column_order]

# Filter data to include only rows from the year 2007 onward
merged_df = merged_df[merged_df['Date'] >= '2007-01-01']

 # Convert 'Date' column to datetime format
merged_df['Date'] = pd.to_datetime(merged_df['Date'])
    
# Display the resulting DataFrame
print(merged_df.head())
# Out:
#         Ticker Company_name   Industry       Date        Open       Close  \
# 0  HINDALCO.NS     HINDALCO  ALUMINIUM 2007-01-02  136.324896  137.522079
# 1  HINDALCO.NS     HINDALCO  ALUMINIUM 2007-01-03  139.028205  138.410309
# 2  HINDALCO.NS     HINDALCO  ALUMINIUM 2007-01-04  138.255819  135.011826
# 3  HINDALCO.NS     HINDALCO  ALUMINIUM 2007-01-05  134.278063  132.154022
# 4  HINDALCO.NS     HINDALCO  ALUMINIUM 2007-01-08  131.381593  129.025848
#
#     Volume
# 0  1737983
# 1  6568517
# 2  5541476
# 3  5296083
# 4  5202449

# %%
# Save result to new csv file
#merged_df.to_csv("clean_NSEI_stocks_data.csv", index=False)

# %% [markdown]
# # NSEI (India1) Stock Market Performance

# %%
# Load the datasets

earthquake_data = pd.read_csv('clean_major_earthquakes.csv') # magnitude >= 6, 2008-2023
india1_stock_data = pd.read_csv('clean_NSEI_stocks_data.csv')

print(earthquake_data.head())
print('---')
print(india1_stock_data.head())
# Out:
#    tsunami  significance   data_type  magnitude              state  longitude  \
# 0        0           613  earthquake        6.3   Papua New Guinea    146.884
# 1        0           557  earthquake        6.0          Indonesia    101.032
# 2        0           671  earthquake        6.6             Canada   -130.746
# 3        0           630  earthquake        6.4             Canada   -130.542
# 4        0           920  earthquake        6.2             Greece     22.693
#
#    latitude  depth        date                   time
# 0    -5.878   34.0  2008-01-01  18:54:59.010000+00:00
# 1    -2.782   35.0  2008-01-04  07:29:18.300000+00:00
# 2    51.254   15.0  2008-01-05  11:01:06.110000+00:00
# 3    51.163   10.0  2008-01-05  11:44:48.170000+00:00
# 4    37.216   75.0  2008-01-06  05:14:20.180000+00:00
# ---
#         Ticker Company_name   Industry        Date        Open       Close  \
# 0  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-02  136.324896  137.522079
# 1  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-03  139.028205  138.410309
# 2  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-04  138.255819  135.011826
# 3  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-05  134.278063  132.154022
# 4  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-08  131.381593  129.025848
#
#     Volume
# 0  1737983
# 1  6568517
# 2  5541476
# 3  5296083
# 4  5202449

# %%
# Convert the 'date', 'Date' column to datetime format and extract the date part.
earthquake_data['date'] = pd.to_datetime(earthquake_data['date']).dt.date
india1_stock_data['Date'] = pd.to_datetime(india1_stock_data['Date']).dt.date

# %%
# Filter Earthquake Data for India
# Define India's approximate latitude and longitude range
india_lat_range = (8.0, 37.0)     # Latitude range for India (from southern tip to northern borders)
india_lon_range = (68.0, 97.0)    # Longitude range for India (from western to eastern borders)

# Filter earthquakes within India's range
india_earthquakes = earthquake_data[
    (earthquake_data['latitude'].between(*india_lat_range)) &
    (earthquake_data['longitude'].between(*india_lon_range))
]

print("Earthquakes in India area:")
print(india_earthquakes)
# Out:
# Earthquakes in India area:
#       tsunami  significance   data_type  magnitude           state  longitude  \
# 5           0           630  earthquake        6.4  western Xizang    85.1660
# 43          0           798  earthquake        7.2           China    81.4670
# 91          0           680  earthquake        6.6           India    91.8240
# 92          0           573  earthquake        6.1           India    91.7120
# 113         0           596  earthquake        6.2           India    91.8140
# 119         0           692  earthquake        6.7           Nepal    83.5200
# 135         0           554  earthquake        6.0           Nepal    83.4870
# 139         0           556  earthquake        6.0     Afghanistan    69.4700
# 140         0           611  earthquake        6.3           China    90.3500
# 177         0           765  earthquake        6.6     Afghanistan    70.7430
# 250         0          1248  earthquake        7.5           India    92.9020
# 269         0           650  earthquake        6.1          Bhutan    91.4370
# 303         0           796  earthquake        6.2     Afghanistan    70.9500
# 308         0           591  earthquake        6.2     Afghanistan    70.7220
# 314         0           554  earthquake        6.0    India region    91.8990
# 390         0           701  earthquake        6.6           India    92.8310
# 457         0           907  earthquake        6.3     Afghanistan    70.7740
# 500         0           713  earthquake        6.2           India    94.6800
# 658         0          1562  earthquake        6.9           India    88.1550
# 774         0           593  earthquake        6.2           China    82.5180
# 803         0           795  earthquake        6.8         Myanmar    95.8850
# 973         0           733  earthquake        6.9           China    82.5864
# 1037        0           587  earthquake        6.0           India    88.0376
# 1155        0          2820  earthquake        7.8           Nepal    84.7314
# 1156        0           650  earthquake        6.1           Nepal    85.5398
# 1157        0           733  earthquake        6.6           Nepal    84.8216
# 1158        0          1016  earthquake        6.7           Nepal    86.0173
# 1167        0          1563  earthquake        7.3           Nepal    86.0655
# 1168        0           651  earthquake        6.3           Nepal    86.1617
# 1238        0          1448  earthquake        7.5     Afghanistan    70.3676
# 1263        0           820  earthquake        6.3     Afghanistan    71.1263
# 1265        0          1515  earthquake        6.7           India    93.6505
# 1297        0           738  earthquake        6.6     Afghanistan    71.1311
# 1298        0           903  earthquake        6.9         Myanmar    94.8654
# 1351        0           981  earthquake        6.8         Myanmar    94.5690
# 1495        0           651  earthquake        6.4           India    94.9838
# 1514        0           711  earthquake        6.0         Myanmar    96.0717
# 1553        0           686  earthquake        6.2      Tajikistan    71.3822
# 1755        0           712  earthquake        6.1     Afghanistan    70.4555
# 1810        0           573  earthquake        6.1           India    94.9362
# 1815        0           650  earthquake        6.3  western Xizang    86.8637
# 1928        0          2228  earthquake        6.0           India    92.4565
# 1956        0           576  earthquake        6.1    India region    94.0192
# 2004        0           930  earthquake        6.2         Myanmar    93.5061
# 2083        0          1074  earthquake        6.0     Afghanistan    69.4639
# 2136        0           564  earthquake        6.0     Afghanistan    70.7455
# 2166        0          1350  earthquake        6.5     Afghanistan    70.9430
#
#       latitude   depth        date                   time
# 5      32.2880   10.00  2008-01-09  08:26:45.490000+00:00
# 43     35.4900   10.00  2008-03-20  22:32:57.930000+00:00
# 91     11.0050   17.00  2008-06-27  11:40:13.990000+00:00
# 92     10.8470   15.00  2008-06-28  12:54:46.360000+00:00
# 113    11.0550   20.00  2008-08-10  08:20:33.420000+00:00
# 119    30.9010   12.00  2008-08-25  13:21:58.820000+00:00
# 135    30.8360    4.00  2008-09-25  01:47:11.190000+00:00
# 139    33.8860   10.00  2008-10-05  22:56:28.930000+00:00
# 140    29.8070   12.00  2008-10-06  08:30:45.570000+00:00
# 177    36.4190  204.80  2009-01-03  20:23:20.180000+00:00
# 250    14.0990   24.00  2009-08-10  19:55:38.730000+00:00
# 269    27.3320   14.00  2009-09-21  08:53:05.910000+00:00
# 303    36.5170  185.90  2009-10-22  19:51:27.520000+00:00
# 308    36.3910  210.00  2009-10-29  17:44:32.060000+00:00
# 314     8.0820   23.00  2009-11-10  02:48:46.790000+00:00
# 390    13.6670   34.00  2010-03-30  16:54:46.730000+00:00
# 457    36.4430  220.10  2010-09-17  19:21:15.010000+00:00
# 500    24.6180   85.00  2011-02-04  13:53:46.260000+00:00
# 658    27.7300   50.00  2011-09-18  12:40:51.830000+00:00
# 774    35.6610   13.00  2012-08-12  10:47:06.450000+00:00
# 803    23.0050   13.70  2012-11-11  01:12:38.870000+00:00
# 973    35.9053   10.00  2014-02-12  09:19:49.060000+00:00
# 1037   18.2012   47.23  2014-05-21  16:21:54.350000+00:00
# 1155   28.2305    8.22  2015-04-25  06:11:25.950000+00:00
# 1156   27.6285   10.00  2015-04-25  06:15:22.910000+00:00
# 1157   28.2244   10.00  2015-04-25  06:45:21.320000+00:00
# 1158   27.7711   22.91  2015-04-26  07:09:10.670000+00:00
# 1167   27.8087   15.00  2015-05-12  07:05:19.730000+00:00
# 1168   27.6250   15.00  2015-05-12  07:36:54.490000+00:00
# 1238   36.5244  231.00  2015-10-26  09:09:42.560000+00:00
# 1263   36.4935  206.00  2015-12-25  19:14:47.190000+00:00
# 1265   24.8036   55.00  2016-01-03  23:05:22.270000+00:00
# 1297   36.4725  212.00  2016-04-10  10:28:58.720000+00:00
# 1298   23.0944  136.00  2016-04-13  13:55:17.800000+00:00
# 1351   20.9228   82.00  2016-08-24  10:34:54.580000+00:00
# 1495   29.8333    8.00  2017-11-17  22:34:19.450000+00:00
# 1514   18.3719    9.00  2018-01-11  18:26:24.240000+00:00
# 1553   36.9942  116.00  2018-05-09  10:41:45.910000+00:00
# 1755   36.5374  212.00  2019-12-20  11:39:52.874000+00:00
# 1810   11.8485   10.00  2020-07-17  14:03:40.437000+00:00
# 1815   33.1438   10.00  2020-07-22  20:07:19.194000+00:00
# 1928   26.7813   34.00  2021-04-28  02:21:26.212000+00:00
# 1956    8.8809   10.00  2021-08-03  03:42:38.345000+00:00
# 2004   22.8232   43.00  2021-11-25  23:45:41.752000+00:00
# 2083   33.0203    4.00  2022-06-21  20:54:34.410000+00:00
# 2136   36.4738  203.00  2023-01-05  14:25:53.019000+00:00
# 2166   36.5230  192.00  2023-03-21  16:47:23.626000+00:00

# %%
# Count the number of earthquakes
num_earthquakes = india_earthquakes[india_earthquakes['data_type'] == 'earthquake'].shape[0]

# Print the result
print(f"Number of earthquakes: {num_earthquakes}")
# Out:
# Number of earthquakes: 47

# %%
# Merge earthquake data with India1 stock data
merged_data = pd.merge(india1_stock_data, india_earthquakes, left_on='Date', right_on='date', how='left')

print(merged_data.head())
# Out:
#         Ticker Company_name   Industry        Date        Open       Close  \
# 0  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-02  136.324896  137.522079
# 1  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-03  139.028205  138.410309
# 2  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-04  138.255819  135.011826
# 3  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-05  134.278063  132.154022
# 4  HINDALCO.NS     HINDALCO  ALUMINIUM  2007-01-08  131.381593  129.025848
#
#     Volume  tsunami  significance data_type  magnitude state  longitude  \
# 0  1737983      NaN           NaN       NaN        NaN   NaN        NaN
# 1  6568517      NaN           NaN       NaN        NaN   NaN        NaN
# 2  5541476      NaN           NaN       NaN        NaN   NaN        NaN
# 3  5296083      NaN           NaN       NaN        NaN   NaN        NaN
# 4  5202449      NaN           NaN       NaN        NaN   NaN        NaN
#
#    latitude  depth date time
# 0       NaN    NaN  NaN  NaN
# 1       NaN    NaN  NaN  NaN
# 2       NaN    NaN  NaN  NaN
# 3       NaN    NaN  NaN  NaN
# 4       NaN    NaN  NaN  NaN

# %% [markdown]
# ## Impact of Earthquakes on Stock Prices by Industry

# %%
# Industry-wise Analysis
## To analyze the impact on different industries, we can group the data by Industry and perform similar analyses.

# Create a new column to indicate if there was an earthquake on that day
merged_data['earthquake'] = merged_data['magnitude'].notna()

# Group by Industry and earthquake to see the average change in stock prices
industry_impact_on_prices = merged_data.groupby(['Industry', 'earthquake']).agg({
    'Open': 'mean',
    'Close': 'mean'
}).reset_index()

# Calculate the percentage change in stock prices
industry_impact_on_prices['price_change'] = (industry_impact_on_prices['Close'] - industry_impact_on_prices['Open']) / industry_impact_on_prices['Open'] * 100

# Visualize the impact on stock prices by industry
plt.figure(figsize=(14, 7))
sns.barplot(x='Industry', y='price_change', hue='earthquake', data=industry_impact_on_prices)
plt.title('Impact of Earthquakes on Stock Prices by Industry')
plt.xlabel('Industry')
plt.ylabel('Percentage Change in Stock Prices')
plt.xticks(rotation=90)
plt.show()

# %%
# Number of Industries Affected
## To determine the number of industries affected by earthquakes, we can count the unique industries in the merged dataset.
unique_industries = merged_data['Industry'].nunique()

print(f"Number of unique industries: {unique_industries}")
# Out:
# Number of unique industries: 21

# %% [markdown]
# # How Market performs before and after earthquake in the range +-30 days?

# %%
# Set parameters
WINDOW_SIZE = 30  # Days before/after earthquake to analyze
BASE_DAYS = 3     # Days before earthquake to use as baseline

# Convert date columns to datetime
merged_data['Date'] = pd.to_datetime(merged_data['Date'])  # merged_data = merge from japan_stock_data and japan_earthquake
earthquake_dates = merged_data[merged_data['earthquake']]['Date'].unique()  # Unique dates prevent duplicate processing of same earthquake

# %%
# Create event study dataframe
## For each earthquake, creates a [-10, +10] day window around it.
event_data = []

for eq_date in earthquake_dates:
    start_date = eq_date - pd.Timedelta(days=WINDOW_SIZE)
    end_date = eq_date + pd.Timedelta(days=WINDOW_SIZE)
    
    window_data = merged_data[
        (merged_data['Date'] >= start_date) & 
        (merged_data['Date'] <= end_date)
    ].copy()
    
    window_data['days_from_event'] = (window_data['Date'] - eq_date).dt.days   # days_from_event: to track the number of days relative to the earthquake
    window_data['earthquake_id'] = eq_date   # earthquake_id : to identify the specific earthquake
    event_data.append(window_data)

# %%
# Combine all event windows and reset index (prevents index conflicts from different windows)
event_study = pd.concat(event_data).reset_index(drop=True)

# Calculate normalized values
def normalize_group(group):
    # Perform normalization on the non-grouping columns
    baseline_mask = (group['days_from_event'] >= -BASE_DAYS) & (group['days_from_event'] < 0)
    baseline = group.loc[baseline_mask, 'Close'].mean()
    
    if pd.notnull(baseline) and baseline != 0:
        group['normalized_close'] = (group['Close'] - baseline) / baseline * 100
    else:
        group['normalized_close'] = np.nan
    
    # Return the necessary columns, including grouping columns
    return group[['Date', 'Close', 'days_from_event', 'normalized_close',
                 'Industry', 'Ticker', 'earthquake_id']]

# %%
# Apply normalization
event_study = (
    event_study.groupby(['Industry', 'Ticker', 'earthquake_id'], group_keys=False)
              .apply(normalize_group)  # Do not use include_groups=False
              .reset_index(drop=True)
)
# Out:
# C:\Users\dongv\AppData\Local\Temp\ipykernel_30876\1083920541.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(normalize_group)  # Do not use include_groups=False

# %%
# Aggregate results
agg_results = event_study.groupby(['Industry', 'days_from_event'], as_index=False).agg(
    mean_change=('normalized_close', 'mean'),
    std_change=('normalized_close', 'std'),
    count=('normalized_close', 'count')
)

# %%
# Visualization
plt.figure(figsize=(14, 8))
sns.lineplot(
    data=agg_results,
    x='days_from_event',
    y='mean_change',
    hue='Industry',
    errorbar=('ci', 95)
)
plt.axvline(0, color='red', linestyle='--', label='Earthquake Day')
plt.axhline(0, color='black', linestyle='-')
plt.title(f'Market Recovery Pattern ({WINDOW_SIZE} Days Window)')
plt.xlabel('Days Relative to Earthquake')
plt.ylabel('Normalized Price Change (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Calculate and sort recovery metrics
recovery_analysis = (
    agg_results[agg_results['days_from_event'] >= 0]
    .groupby('Industry')
    .agg(
        max_impact=('mean_change', lambda x: x.min() if x.min() < 0 else x.max()),
        days_to_recover=('mean_change', lambda x: np.argmax(x >= 0) if any(x >= 0) else np.nan),
        volatility=('std_change', 'mean')
    )
    .reset_index()
    .sort_values('max_impact', ascending=True)  # Sort by most negative impact first
)

print("\nRecovery Metrics (Sorted by Maximum Impact):")
print(recovery_analysis.to_string(index=False))
# Out:
# Recovery Metrics (Sorted by Maximum Impact):
#        Industry  max_impact  days_to_recover  volatility
#         FINANCE   -7.409657                0   11.558543
#           STEEL   -6.357531                3   12.816134
#       ALUMINIUM   -6.320277                3   10.038498
#        TEXTILES   -6.284248               30    8.555909
#          CEMENT   -5.387338                9    8.150063
#         TELECOM   -5.096652                3    5.801659
#         DEFENCE   -3.705755               12    8.519734
#   MISCELLANEOUS   -3.539089               14   10.235205
#          PAINTS   -3.506357                3    5.885539
#     ENGINEERING   -3.447345               12    8.184253
#          ENERGY   -2.690245                5    7.664893
#       RETAILING   -2.513325                3    8.628999
#           POWER   -2.501396                2    6.197660
#         BANKING   -2.276467                3    7.435173
#            FMCG   -1.984024                3    7.181517
# PHARMACEUTICALS   -1.661050                0    6.820758
#        SOFTWARE   -1.649572                3    8.665248
#     AUTOMOBILES   -1.523350                2    8.321596
#       INSURANCE   -1.428017                0    3.878403
#  FOOD & TOBACCO   -1.280784                3    4.664501
#          MINING   -0.708312                0    4.588076
